# %% [markdown]
# # Random Forest Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
#Loading up the coffee data set
coffee_df = pd.read_csv('../data/coffee.csv')

#Creating a copy
coffee = coffee_df.copy()

# %% [markdown]
# Creating a train test split.

# %%
from sklearn.model_selection import train_test_split

# %%
## Make the split, stratify according to country of origin.
coffee_train, coffee_test = train_test_split(coffee.copy(),
                                            shuffle=True,
                                            random_state=47,
                                            test_size=.2,
                                            stratify=coffee['Country_of_Origin'])

# %%
coffee_train.head()
# Out:
#     Country_of_Origin          Processing_Method  Aroma  Flavor  Aftertaste  \
# 196            Mexico  Semi-washed / Semi-pulped   7.83    7.92        7.67
# 465            Brazil     Pulped natural / honey   7.58    7.58        7.58
# 64             Brazil  Semi-washed / Semi-pulped   8.00    8.00        8.00
# 27             Brazil              Natural / Dry   8.50    8.17        8.00
# 718            Mexico               Washed / Wet   7.58    7.58        7.42
#
#      Acidity  Body  Balance  Uniformity  Clean_Cup  Sweetness  Cupper_Points  \
# 196     7.83  7.50     7.75        10.0       10.0       10.0           7.75
# 465     7.50  7.67     7.58        10.0       10.0       10.0           7.58
# 64      7.67  7.75     8.00        10.0       10.0       10.0           8.00
# 27      7.75  8.00     8.00        10.0       10.0       10.0           8.00
# 718     7.42  7.42     7.42        10.0       10.0       10.0           7.42
#
#      altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 196               1450.0                1450.0                1450.0
# 465                905.0                 905.0                 905.0
# 64                1250.0                1250.0                1250.0
# 27                1300.0                1300.0                1300.0
# 718               1338.0                1338.0                1338.0

# %% [markdown]
# Creating a list of our predictor variables

# %%
predictors = ['Aroma', 'Flavor',
       'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean_Cup',
       'Sweetness', 'Cupper_Points']

coffee_train[predictors]
# Out:
#      Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  Clean_Cup  \
# 196   7.83    7.92        7.67     7.83  7.50     7.75        10.0       10.0
# 465   7.58    7.58        7.58     7.50  7.67     7.58        10.0       10.0
# 64    8.00    8.00        8.00     7.67  7.75     8.00        10.0       10.0
# 27    8.50    8.17        8.00     7.75  8.00     8.00        10.0       10.0
# 718   7.58    7.58        7.42     7.42  7.42     7.42        10.0       10.0
# ..     ...     ...         ...      ...   ...      ...         ...        ...
# 836   7.33    7.42        7.33     7.67  7.42     7.25        10.0       10.0
# 877   7.08    7.33        7.58     7.58  7.17     7.50        10.0       10.0
# 431   7.67    7.67        7.50     7.67  7.50     7.67        10.0       10.0
# 845   7.58    7.50        7.25     7.25  7.50     7.25        10.0       10.0
# 11    8.33    8.42        8.08     8.25  8.25     8.00        10.0       10.0
#
#      Sweetness  Cupper_Points
# 196       10.0           7.75
# 465       10.0           7.58
# 64        10.0           8.00
# 27        10.0           8.00
# 718       10.0           7.42
# ..         ...            ...
# 836       10.0           7.33
# 877       10.0           7.33
# 431       10.0           7.50
# 845       10.0           7.33
# 11        10.0           8.58
#
# [1003 rows x 10 columns]

# %%
coffee.Country_of_Origin.value_counts()
# Out:
# Mexico                          236
# Colombia                        183
# Guatemala                       181
# Brazil                          132
# Taiwan                           75
# United States (Hawaii)           73
# Honduras                         52
# Costa Rica                       51
# Ethiopia                         44
# Tanzania, United Republic Of     40
# Thailand                         32
# Nicaragua                        26
# Uganda                           26
# Kenya                            25
# El Salvador                      21
# Indonesia                        20
# China                            16
# Malawi                           11
# Peru                             10
# Name: Country_of_Origin, dtype: int64

# %%
labels = coffee.Country_of_Origin.value_counts().index

# %% [markdown]
# ## Creating the Model

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=47)

num_of_trees = [50, 100, 250, 500, 1000, 1500, 2000]

rf_acc = np.zeros((5, len(num_of_trees)))

i = 0
for train_index, test_index in kfold.split(coffee_train[predictors], coffee_train.Country_of_Origin):
    X_tt = coffee_train[predictors].iloc[train_index,:]
    y_tt = coffee_train.Country_of_Origin.iloc[train_index]
    X_ho = coffee_train[predictors].iloc[test_index,:]
    y_ho = coffee_train.Country_of_Origin.iloc[test_index]
    
    j = 0
    for num_trees in num_of_trees:
        rf = RandomForestClassifier(max_depth=5,
                                       max_samples = 200,
                                       n_estimators = num_trees,
                                       random_state = 47)
        
        rf.fit(X_tt, y_tt)
        pred = rf.predict(X_ho)

                
        rf_acc[i,j] = accuracy_score(y_ho, pred)
        
        j = j + 1
    i = i + 1

# %%
plt.figure(figsize=(12,8))

## Accuracy
plt.plot(range(len(num_of_trees)), np.mean(rf_acc, axis=0), '-o')
plt.ylabel("Accuracy", fontsize=16)

plt.xlabel("Number of Decision Trees", fontsize=16)
plt.xticks(range(len(num_of_trees)),labels = num_of_trees)

plt.show()

# %% [markdown]
# So random forest does not appear to perform better than our decision tree model.
