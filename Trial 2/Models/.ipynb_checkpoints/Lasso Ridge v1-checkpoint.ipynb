# %% [markdown]
# ## Implementing Lasso/Ridge
# We will use Lasso and Ridge to help us with feature selection.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
## first load the data
coffee = pd.read_csv('../data/one_hot_coffee.csv')
coffee = coffee.copy()

# %%
## next perform the train test split
coffee_train, coffee_test = train_test_split(coffee,
                                            shuffle=True,
                                            random_state=47,
                                            test_size = .2)

# %%
## make a baseline
baseline = coffee['rating'].mean()
print(baseline)
# Out:
# 90.4599101988454

# %%
## import the LinearRegression object
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
predictors = ['region_africa_arabia', 'region_caribbean',
       'region_central_america', 'region_hawaii', 'region_asia_pacific',
       'region_south_america', 'type_espresso', 'type_organic',
       'type_fair_trade', 'type_decaffeinated', 'type_pod_capsule',
       'type_blend', 'type_estate', 'Dark', 'Light', 'Medium', 'Medium-Dark', 'Medium-Light', 'Very Dark']

# %% [markdown]
# We are keeping the first linear regression model for comparison to the Lasso and Ridge Methods

# %%
reg = LinearRegression(copy_X = True)

reg.fit(coffee_train[predictors], 
        coffee_train['rating'])
# Out:
# LinearRegression()

# %%
## make the predictions
preds = reg.predict(coffee_train[predictors])
preds_baseline = baseline * np.ones(len(coffee_train))

# %%
## check the mean squared error
mse = mean_squared_error(coffee_train['rating'], preds)
mse_baseline = mean_squared_error(coffee_train['rating'], preds_baseline)
print("The mean squared error for multiple linear regression is", mse)
print("The mean squared error for the baseline is", mse_baseline)
# Out:
# The mean squared error for multiple linear regression is 9.931262169506294
# The mean squared error for the baseline is 15.565458489578745

# %% [markdown]
# Now we make the Lasso and Ridge Models.

# %%
## set values for alpha
alphas = [0.000001,.00001,.0001,.001,.01,.1,.25,.5,.75,1,5,10,25,50,100,1000,10000]

## These will hold our coefficient estimates
ridge_coefs = np.empty((len(alphas),len(predictors)))
lasso_coefs = np.empty((len(alphas),len(predictors)))

## These will hold our mse estimates
ridge_mse = np.empty(len(alphas))
lasso_mse = np.empty(len(alphas))

## for each alpha value
for i in range(len(alphas)):
    ## set up the ridge pipeline
    ## first scale
    ## then make polynomial features
    ## then fit the ridge regression model
    ## max_iter=5000000
    ridge_pipe = Pipeline([#('scale' ,StandardScaler()),
                              ('ridge',Ridge(alpha=alphas[i], max_iter=5000000))])
    
    ## set up the lasso pipeline
    ## same steps as with ridge
    lasso_pipe = Pipeline([#('scale' ,StandardScaler()),
                              ('lasso',Lasso(alpha=alphas[i], max_iter=5000000))])
    
    
    ## fit the ridge
    ridge_pipe.fit(coffee_train[predictors], 
        coffee_train['rating'])
    
    ## fit the lasso
    lasso_pipe.fit(coffee_train[predictors], 
        coffee_train['rating'])

    ## make the predictions
    ridge_preds = ridge_pipe.predict(coffee_train[predictors])
    lasso_preds = lasso_pipe.predict(coffee_train[predictors])
    
    ridge_mse[i] = mean_squared_error(coffee_train['rating'], ridge_preds)
    lasso_mse[i] = mean_squared_error(coffee_train['rating'], lasso_preds)
    
    # record the coefficients
    ridge_coefs[i,:] = ridge_pipe['ridge'].coef_
    lasso_coefs[i,:] = lasso_pipe['lasso'].coef_

# %%
print("Ridge Coefficients")

pd.DataFrame(np.round(ridge_coefs,8),
            columns = [str(i) for i in predictors],
            index = ["alpha=" + str(a) for a in alphas])
# Out:
# Ridge Coefficients
#               region_africa_arabia  region_caribbean  region_central_america  \
# alpha=1e-06               1.881073         -1.733478                0.431393
# alpha=1e-05               1.881073         -1.733477                0.431393
# alpha=0.0001              1.881073         -1.733469                0.431393
# alpha=0.001               1.881074         -1.733382                0.431395
# alpha=0.01                1.881081         -1.732519                0.431414
# alpha=0.1                 1.881153         -1.723934                0.431605
# alpha=0.25                1.881269         -1.709817                0.431920
# alpha=0.5                 1.881455         -1.686805                0.432433
# alpha=0.75                1.881630         -1.664418                0.432932
# alpha=1                   1.881796         -1.642631                0.433418
# alpha=5                   1.883353         -1.359303                0.439738
# alpha=10                  1.883275         -1.120140                0.445069
# alpha=25                  1.876065         -0.738096                0.453272
# alpha=50                  1.852926         -0.476375                0.456722
# alpha=100                 1.789387         -0.284713                0.449791
# alpha=1000                0.946321         -0.041758                0.235631
# alpha=10000               0.162984         -0.004932                0.039441
#
#               region_hawaii  region_asia_pacific  region_south_america  \
# alpha=1e-06        0.931024             0.225973              0.078407
# alpha=1e-05        0.931024             0.225973              0.078407
# alpha=0.0001       0.931023             0.225973              0.078407
# alpha=0.001        0.931012             0.225971              0.078409
# alpha=0.01         0.930903             0.225958              0.078428
# alpha=0.1          0.929811             0.225824              0.078623
# alpha=0.25         0.927995             0.225597              0.078945
# alpha=0.5          0.924977             0.225213              0.079469
# alpha=0.75         0.921971             0.224821              0.079980
# alpha=1            0.918977             0.224421              0.080479
# alpha=5            0.872876             0.217227              0.087089
# alpha=10           0.820293             0.207016              0.092899
# alpha=25           0.692589             0.174698              0.102761
# alpha=50           0.548211             0.125252              0.109327
# alpha=100          0.385104             0.050301              0.110214
# alpha=1000         0.055984            -0.103259              0.046160
# alpha=10000        0.005670            -0.022444              0.007223
#
#               type_espresso  type_organic  type_fair_trade  \
# alpha=1e-06        1.759500     -0.034572         0.096751
# alpha=1e-05        1.759500     -0.034572         0.096751
# alpha=0.0001       1.759500     -0.034571         0.096751
# alpha=0.001        1.759495     -0.034570         0.096749
# alpha=0.01         1.759447     -0.034558         0.096726
# alpha=0.1          1.758969     -0.034432         0.096497
# alpha=0.25         1.758172     -0.034223         0.096115
# alpha=0.5          1.756841     -0.033875         0.095481
# alpha=0.75         1.755508     -0.033529         0.094848
# alpha=1            1.754171     -0.033184         0.094218
# alpha=5            1.732577     -0.027900         0.084472
# alpha=10           1.705490     -0.021994         0.073289
# alpha=25           1.626799     -0.008604         0.046104
# alpha=50           1.507874      0.004093         0.016059
# alpha=100          1.311178      0.013666        -0.015185
# alpha=1000         0.338350      0.003918        -0.037162
# alpha=10000        0.029378     -0.000142        -0.007294
#
#               type_decaffeinated  type_pod_capsule  type_blend  type_estate  \
# alpha=1e-06             0.258168         -1.864663    0.223573     0.607377
# alpha=1e-05             0.258168         -1.864663    0.223573     0.607377
# alpha=0.0001            0.258167         -1.864662    0.223573     0.607377
# alpha=0.001             0.258156         -1.864652    0.223572     0.607377
# alpha=0.01              0.258052         -1.864552    0.223566     0.607375
# alpha=0.1               0.257007         -1.863556    0.223500     0.607358
# alpha=0.25              0.255277         -1.861898    0.223390     0.607330
# alpha=0.5               0.252426         -1.859141    0.223202     0.607291
# alpha=0.75              0.249614         -1.856393    0.223007     0.607258
# alpha=1                 0.246842         -1.853653    0.222807     0.607233
# alpha=5                 0.207218         -1.810990    0.219032     0.607520
# alpha=10                0.167810         -1.760677    0.213404     0.608875
# alpha=25                0.090779         -1.627393    0.194923     0.613825
# alpha=50                0.027101         -1.450190    0.165617     0.617840
# alpha=100              -0.021691         -1.200389    0.118318     0.610842
# alpha=1000             -0.036072         -0.331052   -0.040379     0.323438
# alpha=10000            -0.006385         -0.043940   -0.014636     0.054058
#
#                   Dark     Light    Medium  Medium-Dark  Medium-Light  \
# alpha=1e-06  -3.089036  2.948697  1.467998    -1.043889      2.825813
# alpha=1e-05  -3.089036  2.948697  1.467998    -1.043889      2.825813
# alpha=0.0001 -3.089035  2.948696  1.467998    -1.043889      2.825812
# alpha=0.001  -3.089025  2.948683  1.467993    -1.043891      2.825806
# alpha=0.01   -3.088924  2.948556  1.467944    -1.043909      2.825748
# alpha=0.1    -3.087915  2.947288  1.467458    -1.044085      2.825168
# alpha=0.25   -3.086236  2.945176  1.466648    -1.044377      2.824203
# alpha=0.5    -3.083441  2.941665  1.465302    -1.044860      2.822597
# alpha=0.75   -3.080651  2.938164  1.463960    -1.045340      2.820996
# alpha=1      -3.077868  2.934672  1.462622    -1.045815      2.819398
# alpha=5      -3.034081  2.880033  1.441720    -1.052976      2.794364
# alpha=10     -2.981197  2.814764  1.416742    -1.060958      2.764306
# alpha=25     -2.833432  2.636341  1.347782    -1.080286      2.680888
# alpha=50     -2.617848  2.385533  1.248107    -1.101558      2.559581
# alpha=100    -2.273933  2.005658  1.088977    -1.117987      2.363602
# alpha=1000   -0.702802  0.519535  0.301614    -0.736819      1.178569
# alpha=10000  -0.092922  0.061123  0.021424    -0.137126      0.219107
#
#               Very Dark
# alpha=1e-06   -3.109582
# alpha=1e-05   -3.109582
# alpha=0.0001  -3.109581
# alpha=0.001   -3.109566
# alpha=0.01    -3.109415
# alpha=0.1     -3.107913
# alpha=0.25    -3.105415
# alpha=0.5     -3.101263
# alpha=0.75    -3.097128
# alpha=1       -3.093008
# alpha=5       -3.029060
# alpha=10      -2.953656
# alpha=25      -2.751293
# alpha=50      -2.473816
# alpha=100     -2.066317
# alpha=1000    -0.560098
# alpha=10000   -0.071606

# %%
print("Lasso Coefficients")

pd.DataFrame(np.round(lasso_coefs,8),
            columns = [str(i) for i in predictors],
            index = ["alpha=" + str(a) for a in alphas])
# Out:
# Lasso Coefficients
#               region_africa_arabia  region_caribbean  region_central_america  \
# alpha=1e-06               1.881059         -1.733286                0.431378
# alpha=1e-05               1.880936         -1.731552                0.431248
# alpha=0.0001              1.879699         -1.714220                0.429945
# alpha=0.001               1.867806         -1.540518                0.417186
# alpha=0.01                1.778886         -0.000000                0.319172
# alpha=0.1                 1.396951         -0.000000                0.000000
# alpha=0.25                0.909523         -0.000000                0.000000
# alpha=0.5                 0.000000         -0.000000                0.000000
# alpha=0.75                0.000000         -0.000000                0.000000
# alpha=1                   0.000000         -0.000000                0.000000
# alpha=5                   0.000000         -0.000000                0.000000
# alpha=10                  0.000000         -0.000000                0.000000
# alpha=25                  0.000000         -0.000000                0.000000
# alpha=50                  0.000000         -0.000000                0.000000
# alpha=100                 0.000000         -0.000000                0.000000
# alpha=1000                0.000000         -0.000000                0.000000
# alpha=10000               0.000000         -0.000000                0.000000
#
#               region_hawaii  region_asia_pacific  region_south_america  \
# alpha=1e-06        0.930962             0.225949              0.078386
# alpha=1e-05        0.930400             0.225738              0.078203
# alpha=0.0001       0.924780             0.223621              0.076369
# alpha=0.001        0.869024             0.202867              0.058721
# alpha=0.01         0.353566             0.017605              0.000000
# alpha=0.1          0.000000            -0.000000              0.000000
# alpha=0.25         0.000000            -0.000000              0.000000
# alpha=0.5          0.000000            -0.000000              0.000000
# alpha=0.75         0.000000            -0.000000              0.000000
# alpha=1            0.000000            -0.000000              0.000000
# alpha=5            0.000000            -0.000000              0.000000
# alpha=10           0.000000            -0.000000              0.000000
# alpha=25           0.000000            -0.000000              0.000000
# alpha=50           0.000000            -0.000000              0.000000
# alpha=100          0.000000            -0.000000              0.000000
# alpha=1000         0.000000            -0.000000              0.000000
# alpha=10000        0.000000            -0.000000              0.000000
#
#               type_espresso  type_organic  type_fair_trade  \
# alpha=1e-06        1.759487     -0.034527         0.096702
# alpha=1e-05        1.759368     -0.034124         0.096261
# alpha=0.0001       1.758177     -0.030094         0.091846
# alpha=0.001        1.746357     -0.000000         0.055696
# alpha=0.01         1.637223      0.000000         0.000000
# alpha=0.1          0.539974     -0.000000        -0.000000
# alpha=0.25         0.000000     -0.000000        -0.000000
# alpha=0.5          0.000000      0.000000        -0.000000
# alpha=0.75         0.000000     -0.000000        -0.000000
# alpha=1            0.000000     -0.000000        -0.000000
# alpha=5            0.000000     -0.000000        -0.000000
# alpha=10           0.000000     -0.000000        -0.000000
# alpha=25           0.000000     -0.000000        -0.000000
# alpha=50           0.000000     -0.000000        -0.000000
# alpha=100          0.000000     -0.000000        -0.000000
# alpha=1000         0.000000     -0.000000        -0.000000
# alpha=10000        0.000000     -0.000000        -0.000000
#
#               type_decaffeinated  type_pod_capsule  type_blend  type_estate  \
# alpha=1e-06             0.258055         -1.864633    0.223554     0.607375
# alpha=1e-05             0.257040         -1.864361    0.223388     0.607353
# alpha=0.0001            0.246884         -1.861647    0.221729     0.607136
# alpha=0.001             0.146217         -1.834803    0.205193     0.605028
# alpha=0.01              0.000000         -1.599597    0.042970     0.572975
# alpha=0.1              -0.000000         -0.000000   -0.000000     0.110903
# alpha=0.25             -0.000000         -0.000000   -0.000000     0.000000
# alpha=0.5              -0.000000         -0.000000   -0.000000     0.000000
# alpha=0.75             -0.000000         -0.000000   -0.000000     0.000000
# alpha=1                -0.000000         -0.000000   -0.000000     0.000000
# alpha=5                -0.000000         -0.000000   -0.000000     0.000000
# alpha=10               -0.000000         -0.000000   -0.000000     0.000000
# alpha=25               -0.000000         -0.000000   -0.000000     0.000000
# alpha=50               -0.000000         -0.000000   -0.000000     0.000000
# alpha=100              -0.000000         -0.000000   -0.000000     0.000000
# alpha=1000             -0.000000         -0.000000   -0.000000     0.000000
# alpha=10000            -0.000000         -0.000000   -0.000000     0.000000
#
#                   Dark     Light    Medium  Medium-Dark  Medium-Light  \
# alpha=1e-06  -4.407480  1.630227  0.149535    -2.362342      1.507353
# alpha=1e-05  -4.407366  1.630112  0.149477    -2.362306      1.507325
# alpha=0.0001 -4.406218  1.628954  0.148896    -2.361943      1.507049
# alpha=0.001  -4.394316  1.617513  0.143102    -2.358282      1.504290
# alpha=0.01   -4.267247  1.509792  0.088099    -2.330645      1.478362
# alpha=0.1    -2.535805  0.765107  0.000000    -1.560849      1.537958
# alpha=0.25   -0.000000  0.000000  0.000000    -0.322282      1.506155
# alpha=0.5    -0.000000  0.000000  0.000000    -0.000000      0.656982
# alpha=0.75   -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=1      -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=5      -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=10     -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=25     -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=50     -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=100    -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=1000   -0.000000  0.000000  0.000000    -0.000000      0.000000
# alpha=10000  -0.000000  0.000000  0.000000    -0.000000      0.000000
#
#               Very Dark
# alpha=1e-06   -4.428021
# alpha=1e-05   -4.427856
# alpha=0.0001  -4.426210
# alpha=0.001   -4.409872
# alpha=0.01    -4.242951
# alpha=0.1     -2.048380
# alpha=0.25    -0.000000
# alpha=0.5     -0.000000
# alpha=0.75    -0.000000
# alpha=1       -0.000000
# alpha=5       -0.000000
# alpha=10      -0.000000
# alpha=25      -0.000000
# alpha=50      -0.000000
# alpha=100     -0.000000
# alpha=1000    -0.000000
# alpha=10000   -0.000000

# %%
ridge_mse
# Out:
# array([ 9.93090465,  9.93090465,  9.93090465,  9.93090465,  9.93090466,
#         9.93090561,  9.9309106 ,  9.93092813,  9.93095677,  9.93099609,
#         9.93282083,  9.9374467 ,  9.96145701, 10.02301419, 10.18468621,
#        12.32553232, 14.89728647])

# %%
lasso_mse
# Out:
# array([ 9.93090465,  9.93090472,  9.93091121,  9.93152269,  9.96890211,
#        10.97326893, 13.33703348, 14.80837099, 15.56493585, 15.56493585,
#        15.56493585, 15.56493585, 15.56493585, 15.56493585, 15.56493585,
#        15.56493585, 15.56493585])

# %% [markdown]
# ## Summary
# So it appears both organic and fair trade have little effect on our models.

# %%
predictors = ['region_africa_arabia', 'region_caribbean',
       'region_central_america', 'region_hawaii', 'region_asia_pacific',
       'region_south_america', 'type_espresso',
       'type_decaffeinated', 'type_pod_capsule',
       'type_blend', 'type_estate', 'Dark', 'Light', 'Medium', 'Medium-Dark', 'Medium-Light', 'Very Dark']

# %%
reg = LinearRegression(copy_X = True)

reg.fit(coffee_train[predictors], 
        coffee_train['rating'])

## make the predictions
preds = reg.predict(coffee_train[predictors])
preds_baseline = baseline * np.ones(len(coffee_train))

## check the mean squared error
mse = mean_squared_error(coffee_train['rating'], preds)
mse_baseline = mean_squared_error(coffee_train['rating'], preds_baseline)
print("The mean squared error for multiple linear regression is", mse)
print("The mean squared error for the baseline is", mse_baseline)
# Out:
# The mean squared error for multiple linear regression is 9.93170332430646
# The mean squared error for the baseline is 15.565458489578745
