# %%
#first import packages that might be needed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
#now import the data
raw_data = pd.read_csv("data/arabica_data_cleaned.csv")

# %%
#check the data
raw_data.head(5)
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           1  Arabica                 metad plc          Ethiopia
# 1           2  Arabica                 metad plc          Ethiopia
# 2           3  Arabica  grounds for health admin         Guatemala
# 3           4  Arabica       yidnekachew dabessa          Ethiopia
# 4           5  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# ...

# %%
#get column names
for col in raw_data.columns:
    print(col)
#alternatively
# Out:
# Unnamed: 0
# Species
# Owner
# Country.of.Origin
# Farm.Name
# Lot.Number
# Mill
# ICO.Number
# Company
# Altitude
# Region
# Producer
# Number.of.Bags
# Bag.Weight
# In.Country.Partner
# Harvest.Year
# Grading.Date
# Owner.1
# Variety
# Processing.Method
# Aroma
# Flavor
# Aftertaste
# Acidity
# Body
# Balance
# Uniformity
# Clean.Cup
# Sweetness
# Cupper.Points
# Total.Cup.Points
# Moisture
# Category.One.Defects
# Quakers
# Color
# Category.Two.Defects
# Expiration
# Certification.Body
# Certification.Address
# Certification.Contact
# unit_of_measurement
# altitude_low_meters
# altitude_high_meters
# altitude_mean_meters

# %%
#make a new data frame containing columns we need
coffee = raw_data[["Country.of.Origin", "Altitude", "Region", "Harvest.Year", 
                   "Processing.Method", "Aroma", "Flavor", "Aftertaste", 
                   "Acidity", "Body", "Balance", "Uniformity", "Clean.Cup", 
                   "Sweetness", "Cupper.Points", "Total.Cup.Points",
                   "Moisture", "Quakers", "Color", "altitude_low_meters", 
                   "altitude_high_meters", "altitude_mean_meters"]].copy()

# %%
#check coffee data frame
coffee.head(5)
#further narrowing down of columns will probably be needed
# Out:
#   Country.of.Origin       Altitude        Region Harvest.Year  \
# 0          Ethiopia      1950-2200  guji-hambela         2014
# 1          Ethiopia      1950-2200  guji-hambela         2014
# 2         Guatemala  1600 - 1800 m           NaN          NaN
# 3          Ethiopia      1800-2200        oromia         2014
# 4          Ethiopia      1950-2200  guji-hambela         2014
#
#   Processing.Method  Aroma  Flavor  Aftertaste  Acidity  Body  ...  Clean.Cup  \
# 0      Washed / Wet   8.67    8.83        8.67     8.75  8.50  ...       10.0
# 1      Washed / Wet   8.75    8.67        8.50     8.58  8.42  ...       10.0
# 2               NaN   8.42    8.50        8.42     8.42  8.33  ...       10.0
# 3     Natural / Dry   8.17    8.58        8.42     8.42  8.50  ...       10.0
# 4      Washed / Wet   8.25    8.50        8.25     8.50  8.42  ...       10.0
#
#    Sweetness  Cupper.Points  Total.Cup.Points  Moisture  Quakers  Color  \
# ...

# %%
#rename columns to have underscore instead of period
coffee.columns = coffee.columns.str.replace(".", "_")
coffee.head(5)
# Out:
# C:\Users\Cassidy\AppData\Local\Temp/ipykernel_24596/3609485605.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coffee.columns = coffee.columns.str.replace(".", "_")
#   Country_of_Origin       Altitude        Region Harvest_Year  \
# 0          Ethiopia      1950-2200  guji-hambela         2014
# 1          Ethiopia      1950-2200  guji-hambela         2014
# 2         Guatemala  1600 - 1800 m           NaN          NaN
# 3          Ethiopia      1800-2200        oromia         2014
# 4          Ethiopia      1950-2200  guji-hambela         2014
#
#   Processing_Method  Aroma  Flavor  Aftertaste  Acidity  Body  ...  Clean_Cup  \
# 0      Washed / Wet   8.67    8.83        8.67     8.75  8.50  ...       10.0
# 1      Washed / Wet   8.75    8.67        8.50     8.58  8.42  ...       10.0
# ...

# %%
coffee.loc[:20, "Region"]
# Out:
# 0                    guji-hambela
# 1                    guji-hambela
# 2                             NaN
# 3                          oromia
# 4                    guji-hambela
# 5                             NaN
# 6                             NaN
# 7                          oromia
# 8                         oromiya
# 9     snnp/kaffa zone,gimbowereda
# 10                         oromia
# 11                      antioquia
# 12                      antioquia
# 13                           kona
# 14                        oromiya
# 15                      antioquia
# 16                       sulawesi
# 17                    yirgacheffe
# 18                         yunnan
# 19                          gedio
# 20                      antioquia
# Name: Region, dtype: object
